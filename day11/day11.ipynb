# %%
import numpy as np

def get_list_from_line():
    with open("input.txt", "r") as file:
        for line in file:
            input_list = line.strip().split(" ")
        return input_list
        
stones = get_list_from_line()
print(stones)
print(len(stones))
print(len(stones[0]))
# Out:
# ['4022724', '951333', '0', '21633', '5857', '97', '702', '6']
# 8
# 7

# %%
def remove_extra_zeros(string):
    if string.count("0") == len(string):
        return "0"
    else:
        return string.lstrip("0")

for i in range(1,76):
    print(f"blink: {i}")
    if i > 1 : print(f"num stones: {len(new_stones)}")
    new_stones=[]
    for stone in stones:
        # print("running...")
        # print(f"curr index: {curr_ind}")
        # print(f"current stones: {stones}")
        if int(stone) == 0:
            # print("replace with 1")
            new_stones.append("1")
        elif len(stone) % 2 == 0:
            # print("split")
            firstpart, secondpart = stone[:len(stone)//2], stone[len(stone)//2:]
            new_stones.append(remove_extra_zeros(firstpart))
            new_stones.append(remove_extra_zeros(secondpart))
        else:
            # print("mult by 2024")
            num = int(stone) * 2024
            new_stones.append(str(num))
    stones = new_stones
    # print(f"blink = {i}")
    # print(f"resulting stones = {stones}")



# print(stones)
print(len(stones))
# Out:
# blink: 1
# blink: 2
# num stones: 11
# blink: 3
# num stones: 15
# blink: 4
# num stones: 21
# blink: 5
# num stones: 32
# blink: 6
# num stones: 47
# blink: 7
# num stones: 81
# blink: 8
# num stones: 128
# blink: 9
# num stones: 169
# blink: 10
# num stones: 254
# blink: 11
# num stones: 414
# blink: 12
# num stones: 613
# blink: 13
# num stones: 913
# blink: 14
# num stones: 1391
# blink: 15
# num stones: 2141
# blink: 16
# num stones: 3272
# blink: 17
# num stones: 4827
# blink: 18
# num stones: 7471
# blink: 19
# num stones: 11411
# blink: 20
# num stones: 16942
# blink: 21
# num stones: 26031
# blink: 22
# num stones: 39534
# blink: 23
# num stones: 60104
# blink: 24
# num stones: 91206
# blink: 25
# num stones: 137665
# blink: 26
# num stones: 211306
# blink: 27
# num stones: 319011
# blink: 28
# num stones: 483249
# blink: 29
# num stones: 739135
# blink: 30
# num stones: 1116440
# blink: 31
# num stones: 1698935
# blink: 32
# num stones: 2581517
# blink: 33
# num stones: 3916303
# blink: 34
# num stones: 5966141
# blink: 35
# num stones: 9025075
# blink: 36
# num stones: 13735178
# blink: 37
# num stones: 20895919
# blink: 38
# num stones: 31639091
# blink: 39
# num stones: 48171142
# blink: 40
# num stones: 73097962
# blink: 41
# num stones: 111010874
